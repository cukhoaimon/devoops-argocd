# %%
# %pip install confluent-kafka
# Out:
# Collecting confluent-kafka
#   Downloading confluent_kafka-2.14.0-cp313-cp313-manylinux_2_28_aarch64.whl.metadata (32 kB)
# Downloading confluent_kafka-2.14.0-cp313-cp313-manylinux_2_28_aarch64.whl (3.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.7/3.7 MB 3.7 MB/s  0:00:01m0:00:0100:01
# Installing collected packages: confluent-kafka
# Successfully installed confluent-kafka-2.14.0
# Note: you may need to restart the kernel to use updated packages.

# %%
from confluent_kafka import Producer
import json

conf = {
    'bootstrap.servers': 'my-cluster-kafka-bootstrap.kafka.svc.cluster.local:9092', 
    'client.id': 'jupyter-producer'
}

producer = Producer(conf)

# %%
def delivery_report(err, msg):
    if err is not None:
        print(f"Message delivery failed: {err}")
    else:
        print(f"Message delivered to {msg.topic()} [{msg.partition()}]")

topic = "my-topic"
data = {"user_id": 123, "event": "notebook_test", "status": "success", "data": "phuc dep trai"}

producer.produce(
    topic, 
    key="key_1", 
    value=json.dumps(data), 
    callback=delivery_report
)

producer.flush()
# Out:
# Message delivered to my-topic [0]
# 0
